# %% [markdown]
# <a href="https://colab.research.google.com/github/madhusudhan0211/Machine_Learning/blob/main/Titanic(EDA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("titanic_train.csv")
train.head(30)
# Out:
#     passenger_id  pclass  ...                          home.dest survived
# 0           1216       3  ...                                NaN        1
# 1            699       3  ...                            Croatia        0
# 2           1267       3  ...                                NaN        0
# 3            449       2  ...               Cornwall / Akron, OH        1
# 4            576       2  ...           Barre, Co Washington, VT        0
# 5           1083       3  ...                                NaN        0
# 6            898       3  ...                                NaN        0
# 7            560       2  ...           Finland / Washington, DC        1
# 8           1079       3  ...                                NaN        1
# 9            908       3  ...                                NaN        0
# 10           313       1  ...                    Elkins Park, PA        0
# 11            43       1  ...                   Philadelphia, PA        1
# ...

# %%
train.isnull()
# Out:
#      passenger_id  pclass   name    sex  ...   boat   body  home.dest  survived
# 0           False   False  False  False  ...  False   True       True     False
# 1           False   False  False  False  ...   True   True      False     False
# 2           False   False  False  False  ...   True   True       True     False
# 3           False   False  False  False  ...  False   True      False     False
# 4           False   False  False  False  ...   True   True      False     False
# ..            ...     ...    ...    ...  ...    ...    ...        ...       ...
# 845         False   False  False  False  ...   True   True      False     False
# 846         False   False  False  False  ...   True  False      False     False
# 847         False   False  False  False  ...  False   True      False     False
# 848         False   False  False  False  ...   True   True       True     False
# 849         False   False  False  False  ...   True  False      False     False
#
# ...

# %%
sns.set_style('dark')
sns.countplot(x='pclass',data=train)

# %%
sns.set_style('dark')
sns.countplot(x='survived',hue='survived', data=train, palette='RdBu')

# %%
sns.set_style('dark')
sns.countplot(x='survived',hue='pclass', data=train, palette='BrBG')

# %%
train['fare'].hist(color='Orange', bins=25, figsize=(5,2))
