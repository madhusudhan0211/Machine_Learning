# %% [markdown]
# <a href="https://colab.research.google.com/github/madhusudhan0211/Machine_Learning/blob/main/laptop_price_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('laptop_price.csv',encoding='ISO-8859–1')

# %%
df.head()
# Out:
#    laptop_ID Company      Product  ...  OpSys  Weight Price_euros
# 0          1   Apple  MacBook Pro  ...  macOS  1.37kg     1339.69
# 1          2   Apple  Macbook Air  ...  macOS  1.34kg      898.94
# 2          3      HP       250 G6  ...  No OS  1.86kg      575.00
# 3          4   Apple  MacBook Pro  ...  macOS  1.83kg     2537.45
# 4          5   Apple  MacBook Pro  ...  macOS  1.37kg     1803.60
#
# [5 rows x 13 columns]

# %%
df.set_index('laptop_ID', inplace=True)

# %%
df.head()
# Out:
#           Company      Product   TypeName  ...  OpSys  Weight Price_euros
# laptop_ID                                  ...
# 1           Apple  MacBook Pro  Ultrabook  ...  macOS  1.37kg     1339.69
# 2           Apple  Macbook Air  Ultrabook  ...  macOS  1.34kg      898.94
# 3              HP       250 G6   Notebook  ...  No OS  1.86kg      575.00
# 4           Apple  MacBook Pro  Ultrabook  ...  macOS  1.83kg     2537.45
# 5           Apple  MacBook Pro  Ultrabook  ...  macOS  1.37kg     1803.60
#
# [5 rows x 12 columns]

# %%
find_data = '512GB'

# %%
df['512GB'] = df['Memory'].str.find(find_data)

# %%
df.head()
# Out:
#           Company      Product   TypeName  ...  Weight Price_euros 512GB
# laptop_ID                                  ...
# 1           Apple  MacBook Pro  Ultrabook  ...  1.37kg     1339.69    -1
# 2           Apple  Macbook Air  Ultrabook  ...  1.34kg      898.94    -1
# 3              HP       250 G6   Notebook  ...  1.86kg      575.00    -1
# 4           Apple  MacBook Pro  Ultrabook  ...  1.83kg     2537.45     0
# 5           Apple  MacBook Pro  Ultrabook  ...  1.37kg     1803.60    -1
#
# [5 rows x 13 columns]

# %%
x = df.pop('512GB')

# %%
x = x.replace(to_replace = 0 , value = 1)

# %%
x = x.replace(to_replace = -1 , value = 0)

# %%
x
# Out:
# laptop_ID
# 1       0
# 2       0
# 3       0
# 4       1
# 5       0
#        ..
# 1316    0
# 1317    1
# 1318    0
# 1319    0
# 1320    0
# Name: 512GB, Length: 1303, dtype: int64

# %%
df['512GB'] = x
df.head()
# Out:
#           Company      Product   TypeName  ...  Full HD 512GB (512GB, FULL HD)
# laptop_ID                                  ...
# 1           Apple  MacBook Pro  Ultrabook  ...        0     0                0
# 2           Apple  Macbook Air  Ultrabook  ...        0     0                0
# 3              HP       250 G6   Notebook  ...        0     0                0
# 4           Apple  MacBook Pro  Ultrabook  ...        1     1                1
# 5           Apple  MacBook Pro  Ultrabook  ...        0     0                0
#
# [5 rows x 15 columns]

# %%
find_data_2 = 'IPS Panel Retina Display'

# %%
df['IPS Panel Retina Display'] = df['ScreenResolution'].str.find(find_data_2)

# %%
df.head()
# Out:
#           Company      Product  ... (512GB, FULL HD)  IPS Panel Retina Display
# laptop_ID                       ...
# 1           Apple  MacBook Pro  ...                0                         0
# 2           Apple  Macbook Air  ...                0                        -1
# 3              HP       250 G6  ...                0                        -1
# 4           Apple  MacBook Pro  ...                1                         0
# 5           Apple  MacBook Pro  ...                0                         0
#
# [5 rows x 16 columns]

# %%
x2 = df.pop('IPS Panel Retina Display')

# %%
x2 = x2.replace(to_replace = 0 , value = 1)

# %%
x2 = x2.replace(to_replace = -1 , value = 0)

# %%
x2
# Out:
# laptop_ID
# 1       1
# 2       0
# 3       0
# 4       1
# 5       1
#        ..
# 1316    0
# 1317    0
# 1318    0
# 1319    0
# 1320    0
# Name: IPS Panel Retina Display, Length: 1303, dtype: int64

# %%
df['IPS Panel Retina Display'] = x2
df.head()
# Out:
#           Company      Product  ... (512GB, FULL HD)  IPS Panel Retina Display
# laptop_ID                       ...
# 1           Apple  MacBook Pro  ...                0                         1
# 2           Apple  Macbook Air  ...                0                         0
# 3              HP       250 G6  ...                0                         0
# 4           Apple  MacBook Pro  ...                1                         1
# 5           Apple  MacBook Pro  ...                0                         1
#
# [5 rows x 16 columns]
